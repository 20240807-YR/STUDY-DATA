# %%
import sys
from pathlib import Path

BASE_DIR = Path("/Users/mac/Desktop/project/STUDY-DATA/third_week/12_25")
if str(BASE_DIR) not in sys.path:
    sys.path.append(str(BASE_DIR))

from agent10_rule_engine import generate_message
from map_tone_vector_to_params import ToneAnalyzer
# Out:
# ✅ 모듈 Import 성공
# ✅ ToneAnalyzer 데이터 로드 완료

# %%
from pathlib import Path

BASE = Path("/Users/mac/Desktop/project/STUDY-DATA")
DATA = BASE / "third_week" / "data_csv"

analyzer = ToneAnalyzer.from_files(
    DATA / "tone_vectors.pkl",
    DATA / "tone_metadata_extended.csv"
)

# %%
tone_vector = np.random.rand(1536)

# sims 직접 보기
sims = {
    k: float(
        (tone_vector @ v) / (np.linalg.norm(tone_vector) * np.linalg.norm(v))
    )
    for k, v in analyzer.tone_centroids.items()
}
print("SIMS:", sims)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 6
#       1 tone_vector = np.random.rand(1536)
#       3 # sims 직접 보기
#       4 sims = {
#       5     k: float(
# ----> 6         (tone_vector @ v) / (np.linalg.norm(tone_vector) * np.linalg.norm(v))
#       7     )
#       8     for k, v in analyzer.tone_centroids.items()
#       9 }
#      10 print("SIMS:", sims)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 768 is different from 1536)

# %%
result = generate_message(
    persona="민지",
    tone_vector=tone_vector,
    slot_schema=["intro", "proof", "emotion", "cta"],
    product="레티놀 세럼"
)

result
